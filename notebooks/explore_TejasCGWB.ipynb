# %%
import os
import sys
import datetime
from pathlib import Path
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import geopy
import rasterio
import xlrd

# %%
rootFol = os.path.dirname(os.getcwd())
dataFol = os.path.join(rootFol,"data")

# %%
tejFile = os.path.join(dataFol,"groundwater","CGWB_data_wide.csv")
tej = pd.read_csv(tejFile,usecols=["STATE","DISTRICT","LAT","LON","SITE_TYPE","WLCODE"]) #.drop('Unnamed: 0',axis=1)
tej.head()
# Out:
#   STATE  DISTRICT        LAT        LON SITE_TYPE  WLCODE
# 0    TG  Adilabad  19.087222  78.336111  Dug Well  W26026
# 1    TG  Adilabad  19.087778  78.401111  Dug Well  W26027
# 2    TG  Adilabad  19.170556  77.933611  Dug Well  W26044
# 3    TG  Adilabad  19.176667  78.103611  Dug Well  W26046
# 4    TG  Adilabad  19.160278  78.634444  Dug Well  W26040

# %%
tej.columns
# Out:
# Index(['STATE', 'DISTRICT', 'LAT', 'LON', 'SITE_TYPE', 'WLCODE'], dtype='object')

# %%
cgwbStnFol = os.path.join(dataFol,"groundwater","3_statewise_stationlevel_wloc")

# %%
cgwbStn = pd.read_excel(os.path.join(cgwbStnFol,"groundwater_StateWiseStationLevelReport_Karnataka_monthly_052020_102020.xls"),\
    usecols=["STATE","DISTRICT","STATION","Latitude","Longtitude","Station Type"])
cgwbStn.head()
# Out:
# G:\Users\Craig\miniconda3\envs\geo_env\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#        STATE          DISTRICT        STATION   Latitude  Longtitude  \
# 0  KARNATAKA           DHARWAD     Rayapura A  15.408333   75.061667
# 1  KARNATAKA            MANDYA    Haralahalli  12.483333   76.683333
# 2  KARNATAKA           BELGAUM      Madihalli  16.211667   74.631111
# 3  KARNATAKA        RAMANAGARA  Mahimanahalli  12.391667   77.408333
# 4  KARNATAKA  DAKSHINA KANNADA      Nayanaadu  12.970833   75.150556
#
#   Station Type
# 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual

# %%
cgwbH.head()
# Out:
#   field_1 STATE  DISTRICT          LAT          LON SITE_TYPE  WLCODE  \
# 0       1    TG  Adilabad  19.08722222  78.33611111  Dug Well  W26026
# 1       2    TG  Adilabad  19.08777778  78.40111111  Dug Well  W26027
# 2       3    TG  Adilabad  19.17055556  77.93361111  Dug Well  W26044
# 3       4    TG  Adilabad  19.17666667  78.10361111  Dug Well  W26046
# 4       5    TG  Adilabad  19.16027778  78.63444444  Dug Well  W26040
#
#   May 1996 Aug 1996 Nov 1996  ... Jan 2015 May 2015 Aug 2015 Nov 2015  \
# 0       NA       NA       NA  ...     2.36     3.86     0.91     2.06
# 1       NA       NA       NA  ...     4.03     7.33     2.39      4.3
# 2       NA       NA       NA  ...     3.47    11.72     3.84     6.82
# 3       NA       NA       NA  ...       NA      6.3     1.55     5.18
# 4       NA       NA       NA  ...      3.3     4.78     2.77      3.4
#
#   Jan 2016 May 2016 Aug 2016 Nov 2016 Jan 2017 geometry
# 0     2.32     3.26     1.56     1.71     2.86     None
# ...
